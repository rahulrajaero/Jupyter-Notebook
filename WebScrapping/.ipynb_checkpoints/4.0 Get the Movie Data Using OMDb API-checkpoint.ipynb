# %%
#import the libraries 
import requests
import urllib
import psycopg2
import os

# %% [markdown]
# #### Connect to ```database``` to get the movies title

# %%
try:
    connection = psycopg2.connect(user = 'postgres',
                                 password = '0000!',
                                 host = '127.0.0.1',
                                 port = '5432',
                                 database = 'disney_movies')
    cur = connection.cursor()
    
except:
    print("ERROR_CONNECTING_DATABASE")

# %% [markdown]
# #### Get the ```title```

# %%
cur.execute('''SELECT title FROM movies_table''')
titles = cur.fetchall()
type(titles)
# Out:
# list

# %%
for title in titles:
    print(title[0])
    if title[0] == 'Around the World in 80 Days':
        print()
        print()
# Out:
# The Jungle Book 2
# Academy Award Review of Walt Disney Cartoons
# Snow White and the Seven Dwarfs
# Pinocchio
# Fantasia
# The Reluctant Dragon
# Dumbo
# Dumbo
# Bambi
# Saludos Amigos
# Victory Through Air Power
# The Three Caballeros
# Make Mine Music
# Song of the South
# Fun and Fancy Free
# Melody Time
# So Dear to My Heart
# The Adventures of Ichabod and Mr. Toad
# Cinderella
# Cinderella
# Treasure Island
# Alice in Wonderland
# Alice in Wonderland
# The Story of Robin Hood and His Merrie Men
# Peter Pan
# The Sword and the Rose
# The Living Desert
# Rob Roy, the Highland Rogue
# The Vanishing Prairie
# 20,000 Leagues Under the Sea
# Davy Crockett, King of the Wild Frontier
# Lady and the Tramp
# The African Lion
# The Littlest Outlaw
# The Great Locomotive Chase
# Davy Crockett and the River Pirates
# Secrets of Life
# Westward Ho the Wagons!
# Johnny Tremain
# Perri
# Old Yeller
# The Light in the Forest
# White Wilderness
# Tonka
# Sleeping Beauty
# The Shaggy Dog
# The Shaggy Dog
# Darby O'Gill and the Little People
# Third Man on the Mountain
# Toby Tyler
# Kidnapped
# Pollyanna
# Jungle Cat
# Ten Who Dared
# Swiss Family Robinson
# One Hundred and One Dalmatians
# The Absent-Minded Professor
# The Parent Trap
# Nikki, Wild Dog of the North
# Greyfriars Bobby
# Babes in Toyland
# Moon Pilot
# Bon Voyage!
# Big Red
# Almost Angels
# The Legend of Lobo
# In Search of the Castaways
# Son of Flubber
# Miracle of the White Stallions
# Savage Sam
# Summer Magic
# The Incredible Journey
# The Sword in the Stone
# A Tiger Walks
# The Misadventures of Merlin Jones
# The Three Lives of Thomasina
# The Moon-Spinners
# Mary Poppins
# Emil and the Detectives
# Those Calloways
# The Monkey's Uncle
# That Darn Cat!
# The Ugly Dachshund
# Lt. Robin Crusoe, U.S.N.
# The Fighting Prince of Donegal
# Follow Me, Boys!
# Monkeys, Go Home!
# The Adventures of Bullwhip Griffin
# The Gnome-Mobile
# The Jungle Book
# The Jungle Book
# Charlie, the Lonesome Cougar
# The Happiest Millionaire
# Blackbeard's Ghost
# The One and Only, Genuine, Original Family Band
# Never a Dull Moment
# The Horse in the Gray Flannel Suit
# The Love Bug
# Smith!
# Rascal
# The Computer Wore Tennis Shoes
# King of the Grizzlies
# The Boatniks
# The Wild Country
# The Aristocats
# The Barefoot Executive
# Scandalous John
# Bedknobs and Broomsticks
# The Biscuit Eater
# Now You See Him, Now You Don't
# Napoleon and Samantha
# Run, Cougar, Run
# Snowball Express
# The World's Greatest Athlete
# Charley and the Angel
# Robin Hood
# Superdad
# Herbie Rides Again
# The Bears and I
# The Castaway Cowboy
# The Island at the Top of the World
# The Strongest Man in the World
# Escape to Witch Mountain
# The Apple Dumpling Gang
# The Best of Walt Disney's True-Life Adventures
# Ride a Wild Pony
# No Deposit, No Return
# Treasure of Matecumbe
# Gus
# The Shaggy D.A.
# Freaky Friday
# Freaky Friday
# The Many Adventures of Winnie the Pooh
# A Tale of Two Critters
# The Rescuers
# Herbie Goes to Monte Carlo
# Pete's Dragon
# Pete's Dragon
# Candleshoe
# Return from Witch Mountain
# The Cat from Outer Space
# Hot Lead and Cold Feet
# The North Avenue Irregulars
# The Apple Dumpling Gang Rides Again
# Unidentified Flying Oddball
# The Black Hole
# Midnight Madness
# The Watcher in the Woods
# Herbie Goes Bananas
# The Last Flight of Noah's Ark
# The Devil and Max Devlin
# Amy
# The Fox and the Hound
# Condorman
# Night Crossing
# Tron
# Tex
# Trenchcoat
# Something Wicked This Way Comes
# Never Cry Wolf
# Return to Oz
# The Black Cauldron
# The Journey of Natty Gann
# One Magic Christmas
# The Great Mouse Detective
# Flight of the Navigator
# Benji the Hunted
# Oliver & Company
# Honey, I Shrunk the Kids
# Cheetah
# The Little Mermaid
# Fantasia 2000
# The Tigger Movie
# Dinosaur
# 102 Dalmatians
# The Emperor's New Groove
# Recess: School's Out
# Atlantis: The Lost Empire
# The Princess Diaries
# Max Keeble's Big Move
# Monsters, Inc.
# Snow Dogs
# Return to Never Land
# The Rookie
# Lilo & Stitch
# The Country Bears
# Tuck Everlasting
# The Santa Clause 2
# Treasure Planet
# The Jungle Book 2
# Piglet's Big Movie
# Ghosts of the Abyss
# Holes
# The Lizzie McGuire Movie
# Finding Nemo
# Pirates of the Caribbean: The Curse of the Black Pearl
# Freaky Friday
# Freaky Friday
# Brother Bear
# The Haunted Mansion
# The Young Black Stallion
# Teacher's Pet
# Miracle
# Confessions of a Teenage Drama Queen
# Home on the Range
# Sacred Planet
# Around the World in 80 Days
#
#
# America's Heart and Soul
# The Princess Diaries 2: Royal Engagement
# The Incredibles
# National Treasure
# Aliens of the Deep
# Pooh's Heffalump Movie
# The Pacifier
# Ice Princess
# Herbie: Fully Loaded
# Sky High
# The Greatest Game Ever Played
# Chicken Little
# The Chronicles of Narnia: The Lion, the Witch and the Wardrobe
# Glory Road
# Roving Mars
# Eight Below
# The Shaggy Dog
# The Shaggy Dog
# The Wild
# Cars
# Pirates of the Caribbean: Dead Man's Chest
# Invincible
# The Santa Clause 3: The Escape Clause
# Bridge to Terabithia
# Meet the Robinsons
# Pirates of the Caribbean: At World's End
# Ratatouille
# Underdog
# The Pixar Story
# The Game Plan
# Enchanted
# National Treasure: Book of Secrets
# Hannah Montana and Miley Cyrus: Best of Both Worlds Concert
# College Road Trip
# The Chronicles of Narnia: Prince Caspian
# WALL-E
# Beverly Hills Chihuahua
# Morning Light
# High School Musical 3: Senior Year
# Bolt
# Bedtime Stories
# Jonas Brothers: The 3D Concert Experience
# Race to Witch Mountain
# Hannah Montana: The Movie
# Up
# Lilly the Witch: The Dragon and the Magic Book
# G-Force
# Walt & El Grupo
# Old Dogs
# The Princess and the Frog
# Alice in Wonderland
# Alice in Wonderland
# Prince of Persia: The Sands of Time
# Toy Story 3
# The Sorcerer's Apprentice
# The Crimson Wing: Mystery of the Flamingos
# Secretariat
# Do Dooni Chaar
# Tangled
# The Boys: The Sherman Brothers' Story
# Tron: Legacy
# Anaganaga O Dheerudu
# Lilly the Witch: The Journey to Mandolan
# Mars Needs Moms
# Zokkomon
# African Cats
# Prom
# Pirates of the Caribbean: On Stranger Tides
# Cars 2
# Winnie the Pooh
# The Muppets
# John Carter
# Chimpanzee
# Arjun: The Warrior Prince
# Brave
# The Odd Life of Timothy Green
# Frankenweenie
# Wreck-It Ralph
# Oz the Great and Powerful
# Wings of Life
# Monsters University
# The Lone Ranger
# Planes
# Frozen
# Saving Mr. Banks
# Muppets Most Wanted
# Bears
# Million Dollar Arm
# Maleficent
# Planes: Fire & Rescue
# Alexander and the Terrible, Horrible, No Good, Very Bad Day
# Big Hero 6
# Into the Woods
# McFarland, USA
# Cinderella
# Cinderella
# Monkey Kingdom
# Tomorrowland
# Inside Out
# ABCD 2
# The Good Dinosaur
# The Finest Hours
# Zootopia
# The Jungle Book
# The Jungle Book
# Alice Through the Looking Glass
# Finding Dory
# Pete's Dragon
# Pete's Dragon
# Queen of Katwe
# Moana
# Dangal
# Beauty and the Beast
# Pirates of the Caribbean: Dead Men Tell No Tales
# Cars 3
# Ghost of the Mountains
# Jagga Jasoos
# Coco
# A Wrinkle in Time
# Incredibles 2
# Christopher Robin
# The Nutcracker and the Four Realms
# Ralph Breaks the Internet
# Mary Poppins Returns
# Dumbo
# Dumbo
# Penguins
# Aladdin
# Toy Story 4
# The Lion King
# Maleficent: Mistress of Evil
# Lady and the Tramp
# Frozen II
# Onward

# %%
base_url = 'http://www.omdbapi.com/?'
def get_data_from_OMDb(title):
    parameters = {'t':title, 'apikey':os.environ['OMDb_API_KEY']}
    full_url = base_url + urllib.parse.urlencode(parameters)
    return requests.get(full_url).json()

# %%
title = 'America's Heart and Soul'
get_data_from_OMDb('America\'s Heart and Soul')

# %%
res = get_data_from_OMDb('The Jungle Book')
print(res)
# Out:
# {'Title': 'The Jungle Book', 'Year': '2016', 'Rated': 'PG', 'Released': '15 Apr 2016', 'Runtime': '106 min', 'Genre': 'Adventure, Drama, Family, Fantasy', 'Director': 'Jon Favreau', 'Writer': 'Justin Marks (screenplay by), Rudyard Kipling (based on the books by)', 'Actors': 'Neel Sethi, Bill Murray, Ben Kingsley, Idris Elba', 'Plot': 'After a threat from the tiger Shere Khan forces him to flee the jungle, a man-cub named Mowgli embarks on a journey of self discovery with the help of panther Bagheera and free-spirited bear Baloo.', 'Language': 'English', 'Country': 'UK, USA', 'Awards': 'Won 1 Oscar. Another 32 wins & 55 nominations.', 'Poster': 'https://m.media-amazon.com/images/M/MV5BMTc3NTUzNTI4MV5BMl5BanBnXkFtZTgwNjU0NjU5NzE@._V1_SX300.jpg', 'Ratings': [{'Source': 'Internet Movie Database', 'Value': '7.4/10'}, {'Source': 'Rotten Tomatoes', 'Value': '94%'}, {'Source': 'Metacritic', 'Value': '77/100'}], 'Metascore': '77', 'imdbRating': '7.4', 'imdbVotes': '255,790', 'imdbID': 'tt3040964', 'Type': 'movie', 'DVD': 'N/A', 'BoxOffice': 'N/A', 'Production': 'Fairview Entertainment', 'Website': 'N/A', 'Response': 'True'}

# %%
create_omdb_data = '''CREATE TABLE omdb(
                        id BIGSERIAL NOT NULL,
                        Title TEXT,
                        Genre TEXT,
                        Metascore VARCHAR(20),
                        imdbRating DECIMAL,
                        imdbVotes VARCHAR(20),
                        imdbID VARCHAR(25),
                        rotten_Tomatoes VARCHAR(10));'''
cur.execute(create_omdb_data)
connection.commit()

# %%
def get_rotten_tomatoes_score(movie_info):
    ratings = movie_info.get('Ratings',[])
    for rating in ratings:
        if rating['Source'] == 'Rotten Tomatoes':
            return rating['Value']
        return None

# %%
print(get_rotten_tomatoes_score(res))
# Out:
# None

# %%
index = 1
total = len(titles)
for title in titles:
    try:
        
        movie_info = get_data_from_OMDb(title)
        rotten_Tomatoes = get_rotten_tomatoes_score(movie_info)
        insert_query = '''
                            INSERT INTO omdb(Title, Genre, Metascore, imdbRating, imdbVotes, imdbID, rotten_Tomatoes)
                            VALUES(%s, %s, %s, %s, %s, %s, %s)'''
        record_to_insert = (movie_info['Title'], movie_info['Genre'], movie_info['Metascore'], movie_info['imdbRating'], movie_info['imdbVotes'], movie_info['imdbID'], rotten_Tomatoes)

        # insert into database
        cur.execute(insert_query, record_to_insert)
        connection.commit()
        print(index, total, "-----", movie_info['Title'], "Insertion Successful!")
        index += 1
        
    except:
        print('00000Xa0000000000000 ERROR')
# Out:
# The Jungle Book 2 Insertion Successful!
# Academy Award Review of Walt Disney Cartoons Insertion Successful!
# Snow White and the Seven Dwarfs Insertion Successful!
# Pinocchio Insertion Successful!
# Fantasia Insertion Successful!
# The Reluctant Dragon Insertion Successful!
# Dumbo Insertion Successful!
# Dumbo Insertion Successful!
# Bambi Insertion Successful!
# Saludos Amigos Insertion Successful!
# Victory Through Air Power Insertion Successful!
# The Three Caballeros Insertion Successful!
# Make Mine Music Insertion Successful!
# Song of the South Insertion Successful!
# Fun and Fancy Free Insertion Successful!
# Melody Time Insertion Successful!
# So Dear to My Heart Insertion Successful!
# The Adventures of Ichabod and Mr. Toad Insertion Successful!
# Cinderella Man Insertion Successful!
# Cinderella Man Insertion Successful!
# Muppet Treasure Island Insertion Successful!
# Alice in Wonderland Insertion Successful!
# Alice in Wonderland Insertion Successful!
# The Story of Robin Hood and His Merrie Men Insertion Successful!
# Peter Pan Insertion Successful!
# The Sword and the Rose Insertion Successful!
# The Living Desert Insertion Successful!
# Rob Roy: The Highland Rogue Insertion Successful!
# The Vanishing Prairie Insertion Successful!
# 20,000 Leagues Under the Sea Insertion Successful!
# Davy Crockett: King of the Wild Frontier Insertion Successful!
# Lady and the Tramp Insertion Successful!
# The African Lion Insertion Successful!
# The Littlest Outlaw Insertion Successful!
# The Great Locomotive Chase Insertion Successful!
# Davy Crockett and the River Pirates Insertion Successful!
# Secrets of Life Insertion Successful!
# Westward Ho, the Wagons! Insertion Successful!
# Johnny Tremain Insertion Successful!
# Perri Insertion Successful!
# Old Yeller Insertion Successful!
# The Light in the Forest Insertion Successful!
# White Wilderness Insertion Successful!
# Tonka Insertion Successful!
# Sleeping Beauty Insertion Successful!
# The Shaggy Dog Insertion Successful!
# The Shaggy Dog Insertion Successful!
# Darby O'Gill and the Little People Insertion Successful!
# Third Man on the Mountain Insertion Successful!
# Toby Tyler or Ten Weeks with a Circus Insertion Successful!
# Kidnapped Insertion Successful!
# Pollyanna Insertion Successful!
# Jungle Cat Insertion Successful!
# Ten Who Dared Insertion Successful!
# Swiss Family Robinson Insertion Successful!
# One Hundred and One Dalmatians Insertion Successful!
# The Absent Minded Professor Insertion Successful!
# The Parent Trap Insertion Successful!
# Nikki, Wild Dog of the North Insertion Successful!
# Greyfriars Bobby: The True Story of a Dog Insertion Successful!
# Babes in Toyland Insertion Successful!
# Moon Pilot Insertion Successful!
# Bon voyage Insertion Successful!
# The Big Red One Insertion Successful!
# Almost Angels Insertion Successful!
# The Legend of Lobo Insertion Successful!
# In Search of the Castaways Insertion Successful!
# Son of Flubber Insertion Successful!
# Miracle of the White Stallions Insertion Successful!
# Savage Sam Insertion Successful!
# Summer Magic Insertion Successful!
# Homeward Bound: The Incredible Journey Insertion Successful!
# The Sword in the Stone Insertion Successful!
# A Tiger Walks Insertion Successful!
# The Misadventures of Merlin Jones Insertion Successful!
# The Three Lives of Thomasina Insertion Successful!
# The Moon-Spinners Insertion Successful!
# Mary Poppins Insertion Successful!
# Emil and the Detectives Insertion Successful!
# Those Calloways Insertion Successful!
# The Monkey's Uncle Insertion Successful!
# That Darn Cat! Insertion Successful!
# The Ugly Dachshund Insertion Successful!
# Lt. Robin Crusoe, U.S.N. Insertion Successful!
# The Fighting Prince of Donegal Insertion Successful!
# Follow Me, Boys! Insertion Successful!
# Monkeys, Go Home! Insertion Successful!
# The Adventures of Bullwhip Griffin Insertion Successful!
# The Gnome-Mobile Insertion Successful!
# The Jungle Book Insertion Successful!
# The Jungle Book Insertion Successful!
# Charlie, the Lonesome Cougar Insertion Successful!
# The Happiest Millionaire Insertion Successful!
# Blackbeard's Ghost Insertion Successful!
# The One and Only, Genuine, Original Family Band Insertion Successful!
# Never a Dull Moment Insertion Successful!
# The Horse in the Gray Flannel Suit Insertion Successful!
# The Love Bug Insertion Successful!
# Mr. & Mrs. Smith Insertion Successful!
# Rascal Does Not Dream of Bunny Girl Senpai Insertion Successful!
# The Computer Wore Tennis Shoes Insertion Successful!
# King of the Grizzlies Insertion Successful!
# The Boatniks Insertion Successful!
# The Wild Country Insertion Successful!
# The Aristocats Insertion Successful!
# The Barefoot Executive Insertion Successful!
# Scandalous John Insertion Successful!
# Bedknobs and Broomsticks Insertion Successful!
# The Biscuit Eater Insertion Successful!
# Now You See Him, Now You Don't Insertion Successful!
# Napoleon and Samantha Insertion Successful!
# Run, Cougar, Run Insertion Successful!
# Snowball Express Insertion Successful!
# The World's Greatest Athlete Insertion Successful!
# Charley and the Angel Insertion Successful!
# Robin Hood Insertion Successful!
# Superdad Insertion Successful!
# Herbie Rides Again Insertion Successful!
# The Bears and I Insertion Successful!
# The Castaway Cowboy Insertion Successful!
# The Island at the Top of the World Insertion Successful!
# The Strongest Man in the World Insertion Successful!
# Escape to Witch Mountain Insertion Successful!
# The Apple Dumpling Gang Insertion Successful!
# The Best of Walt Disney's True-Life Adventures Insertion Successful!
# Ride a Wild Pony Insertion Successful!
# No Deposit, No Return Insertion Successful!
# Treasure of Matecumbe Insertion Successful!
# Gus Insertion Successful!
# The Shaggy D.A. Insertion Successful!
# Freaky Friday Insertion Successful!
# Freaky Friday Insertion Successful!
# The Many Adventures of Winnie the Pooh Insertion Successful!
# A Tale of Two Critters Insertion Successful!
# The Rescuers Insertion Successful!
# Herbie Goes to Monte Carlo Insertion Successful!
# Pete's Dragon Insertion Successful!
# Pete's Dragon Insertion Successful!
# Candleshoe Insertion Successful!
# Return from Witch Mountain Insertion Successful!
# The Cat from Outer Space Insertion Successful!
# Hot Lead and Cold Feet Insertion Successful!
# The North Avenue Irregulars Insertion Successful!
# The Apple Dumpling Gang Rides Again Insertion Successful!
# Unidentified Flying Oddball Insertion Successful!
# The Black Hole Insertion Successful!
# Midnight Madness Insertion Successful!
# The Watcher in the Woods Insertion Successful!
# Herbie Goes Bananas Insertion Successful!
# The Last Flight of Noah's Ark Insertion Successful!
# The Devil and Max Devlin Insertion Successful!
# Chasing Amy Insertion Successful!
# The Fox and the Hound Insertion Successful!
# Condorman Insertion Successful!
# Night Crossing Insertion Successful!
# TRON: Legacy Insertion Successful!
# Tex Insertion Successful!
# Trenchcoat Insertion Successful!
# Something Wicked This Way Comes Insertion Successful!
# Never Cry Wolf Insertion Successful!
# Return to Oz Insertion Successful!
# The Black Cauldron Insertion Successful!
# The Journey of Natty Gann Insertion Successful!
# One Magic Christmas Insertion Successful!
# The Great Mouse Detective Insertion Successful!
# Flight of the Navigator Insertion Successful!
# Benji the Hunted Insertion Successful!
# Oliver & Company Insertion Successful!
# Honey, I Shrunk the Kids Insertion Successful!
# The Cheetah Girls Insertion Successful!
# The Little Mermaid Insertion Successful!
# Fantasia 2000 Insertion Successful!
# The Tigger Movie Insertion Successful!
# The Good Dinosaur Insertion Successful!
# 102 Dalmatians Insertion Successful!
# The Emperor's New Groove Insertion Successful!
# Recess: School's Out Insertion Successful!
# Atlantis: The Lost Empire Insertion Successful!
# The Princess Diaries Insertion Successful!
# Max Keeble's Big Move Insertion Successful!
# Monsters, Inc. Insertion Successful!
# Snow Dogs Insertion Successful!
# Peter Pan 2: Return to Never Land Insertion Successful!
# The Rookie Insertion Successful!
# Lilo & Stitch Insertion Successful!
# The Country Bears Insertion Successful!
# Tuck Everlasting Insertion Successful!
# The Santa Clause 2 Insertion Successful!
# Treasure Planet Insertion Successful!
# The Jungle Book 2 Insertion Successful!
# Piglet's Big Movie Insertion Successful!
# Ghosts of the Abyss Insertion Successful!
# Holes Insertion Successful!
# The Lizzie McGuire Movie Insertion Successful!
# Finding Nemo Insertion Successful!
# Pirates of the Caribbean: The Curse of the Black Pearl Insertion Successful!
# Freaky Friday Insertion Successful!
# Freaky Friday Insertion Successful!
# Brother Bear Insertion Successful!
# The Haunted Mansion Insertion Successful!
# The Young Black Stallion Insertion Successful!
# Teacher's Pet Insertion Successful!
# Miracle Insertion Successful!
# Confessions of a Teenage Drama Queen Insertion Successful!
# Home on the Range Insertion Successful!
# Sacred Planet Insertion Successful!
# Around the World in 80 Days Insertion Successful!
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-48-7c8766345268> in <module>
#       5                         INSERT INTO omdb(Title, Genre, Metascore, imdbRating, imdbVotes, imdbID, rotten_Tomatoes)
#       6                         VALUES(%s, %s, %s, %s, %s, %s, %s)'''
# ----> 7     record_to_insert = (movie_info['Title'], movie_info['Genre'], movie_info['Metascore'], movie_info['imdbRating'], movie_info['imdbVotes'], movie_info['imdbID'], rotten_Tomatoes)
#       8
#       9     # insert into database
#
# KeyError: 'Title'

# %%
if connection:
    cur.close()
    connection.close()
    print("Connection Closed!")
# Out:
# Connection Closed!
